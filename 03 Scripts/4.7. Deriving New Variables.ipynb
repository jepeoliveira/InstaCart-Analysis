# %% [markdown]
# ##  4.7: Deriving New Variables
# ## STEPS ##:# p 1a. Create “price_label” colum
# # tep 1b. Create "busiest_day" colum#
# Step 2. Update "busiest day" column to "busiest days" to identify order day of the week as "Busiest days," "Slowest days," or "Regularly bu#
#
# Step 3. Check values of new "busiest days" column for accuracy with observations in markdown f# .
#
# Step 4. Create new column "busiest_period_of_day" to identify time periods “Most orders,” “Average orders,” and “Fewest # s.”
#
# Step 5. Print frequency of "busiest_period_of_da# lumn.
#
# Step 7. Export dataframe as a pickle file to “Prepare ## Data” folder.

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Create a path to main folder

# %%
path = r'C:\Users\João Pedro\MAR-Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\João Pedro\\MAR-Instacart Basket Analysis'

# %% [markdown]
# # Import ords_prods_merge

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %% [markdown]
# # 1A CREATE 'price_label' column

# %% [markdown]
# # Create a subset of first million rows

# %%
df = df_ords_prods_merge[:1000000]

# %% [markdown]
# # Define a function for price labels

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %% [markdown]
# # Apply price range function. Note to self: Python can technically execute this, but it will suggest the loc() method instead.

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\João Pedro\AppData\Local\Temp\ipykernel_5968\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    652638
# Low-range product    338018
# High range             9344
# Name: count, dtype: int64

# %% [markdown]
# # Find most expensive product

# %%
df['prices'].max()
# Out:
# 24.5

# %% [markdown]
# # Use loc() method on df subset to apply price range function.

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\João Pedro\AppData\Local\Temp\ipykernel_5968\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     652638
# Low-range product     338018
# High-range product      9344
# Name: count, dtype: int64

# %% [markdown]
# # Use loc() method on entire ords_prods_merge dataframe to apply price range function.

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# # 1B CREATE 'busiest_day' column

# %% [markdown]
# # Change "order_dow" column name to "order_day_of_week."

# %%
df_ords_prods_merge.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %% [markdown]
# # Find frequency of orders_day_of_week.

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# # Use for-loop to determine whether orders are on "busiest day" (0 = Saturday), "least busy" (4 = Wednesday), or "regularly busy" (other days of the week).

# %%
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# # Create new column in ords_prods_merge to view results in context.

# %%
df_ords_prods_merge['busiest_day'] = result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # 2. Update "busiest day" column to "busiest days" to identify order day of the week as "Busiest days," "Slowest days," or "Regularly busy."

# %% [markdown]
# # Create column “busiest_days" from "orders_day_of_week" to identify two busiest days (0, 1), slowest days (4, 3), or regularly busy (all other days).

# %%
result_2 = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_2.append("Busiest days")
  elif value == 4 or value == 3:
    result_2.append("Slowest days")
  else:
    result_2.append("Regularly busy")

# %%
result_2
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
# ...

# %% [markdown]
#  # 3. Check values of new "busiest days" column for accuracy with observations in markdown format

# %% [markdown]
# # Create new 'busiest_days' column in ords_prods_merge to view results in context.

# %%
df_ords_prods_merge['busiest_days'] = result_2

# %%
df_ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: count, dtype: int64

# %% [markdown]
# # Check output of ords_prods_merge with new "busiest days" column.

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %% [markdown]
# ## The cumulative value count of the ords_prods_merge dataframe equates to the combined sum of all categories ("Regularly busy," "Busiest days," and "Slowest days"). Moreover, the aggregated totals for each category align with the summation of orders on corresponding days of the week (for instance, the total orders during "Busiest days" amount to 11,864,412, which mirrors the sum of orders made on days 0 and 1, totaling 6,204,182 and 5,660,230 respectively). ##

# %% [markdown]
# # 4. Create new column "busiest_period_of_day" to identify time periods “Most orders,” “Average orders,” and “Fewest orders.” #

# %% [markdown]
# # Check value counts in "order_hour_of_day" column.

# %%
df_ords_prods_merge['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
#  ## The value counts provided will be divided evenly among three categories: "Most orders" includes values 10, 11, 14, 15, 13, 12, 16, and 9; "Fewest orders" consists of values 23, 6, 0, 1, 5, 2, 4, and 3; while "Average orders" encompasses all other values in order_hour_of_day. ##

# %% [markdown]
# # Create for-loop if statement labeling periods of time as “Most orders,” “Average orders,” and “Fewest orders.”

# %%
result_3 = []

for value in df_ords_prods_merge["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    result_3.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    result_3.append("Fewest orders")
  else:
    result_3.append("Average orders")

# %%
result_3
# Out:
# ['Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %% [markdown]
# # Create new column "busiest_period_of_day" in ords_prods_merge.

# %%
df_ords_prods_merge['busiest_period_of_day'] = result_3

# %% [markdown]
#  # 5. Print frequency of "busiest_period_of_day" column

# %% [markdown]
# # Print value counts in "busiest_period_of_day" column.

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
#  # 7. Export dataframe as a pickle file to “Prepared Data” folder

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))
