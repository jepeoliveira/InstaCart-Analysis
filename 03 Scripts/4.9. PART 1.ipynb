# %% [markdown]
#  ### TASK 4.19 PART 1 ###

# %% [markdown]
# # 3 IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # IMPORT DATA

# %% [markdown]
# # creat path to main folder

# %%
path = r'C:\Users\João Pedro\MAR-Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\João Pedro\\MAR-Instacart Basket Analysis'

# %% [markdown]
# # Import dataset

# %%
df=pd.read_csv(os.path.join(path,'02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# # 4 Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don't add anything to your analysis #

# %% [markdown]
# # Rename columns

# %%
df.rename(columns={'Surnam':'surname', 'fam_status':'family_status','STATE':'State','n_dependants':'dependants','First Name':'first_name','Gender':'gender' ,'State' : 'state' ,'Age' :'age' }, inplace=True)

# %% [markdown]
# # Check output

# %%
df.head()
# Out:
#    user_id first_name   surname  gender       State  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependants family_status  income
# 0           3       married  165665
# 1           0        single   59285
# 2           2       married   99568
# 3           0        single   42049
# 4           1       married   40374

# %% [markdown]
# # 5 Complete the fundamental data quality and consistency checks youâ€™ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data #

# %% [markdown]
# ## Check duplicated data

# %%
duplicated = df[df.duplicated()]

# %%
duplicated
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, surname, gender, State, age, date_joined, dependants, family_status, income]
# Index: []

# %%
# No duplicated rows

# %% [markdown]
# ## Check for missing values

# %%
df.isnull().sum()
# Out:
# user_id              0
# first_name       11259
# surname              0
# gender               0
# State                0
# age                  0
# date_joined          0
# dependants           0
# family_status        0
# income               0
# dtype: int64

# %%
df[df['first_name'].isnull()]
# Out:
#         user_id first_name   surname  gender         State  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         dependants family_status  income
# ...

# %% [markdown]
# There are missing values in the 'first_name' column

# %% [markdown]
#  # CHECKING DATA TYPES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        206209 non-null  int64
#  1   first_name     194950 non-null  object
#  2   surname        206209 non-null  object
#  3   gender         206209 non-null  object
#  4   State          206209 non-null  object
#  5   age            206209 non-null  int64
#  6   date_joined    206209 non-null  object
#  7   dependants     206209 non-null  int64
#  8   family_status  206209 non-null  object
#  9   income         206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
#  # Need to perform the changing of data_joined dtype

# %%
df['date_joined']=pd.to_datetime(df['date_joined'])

# %% [markdown]
# # checking output

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        206209 non-null  int64
#  1   first_name     194950 non-null  object
#  2   surname        206209 non-null  object
#  3   gender         206209 non-null  object
#  4   State          206209 non-null  object
#  5   age            206209 non-null  int64
#  6   date_joined    206209 non-null  datetime64[ns]
#  7   dependants     206209 non-null  int64
#  8   family_status  206209 non-null  object
#  9   income         206209 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 15.7+ MB

# %% [markdown]
#  # 6. Combine your customer data with the rest of your prepared Instacart data #

# %% [markdown]
# # Import files

# %%
df_large=pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'ords_prods_grouped.pkl'))

# %% [markdown]
# # CHECK OUTPUT

# %%
df_large.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    ...    price_range_loc     busiest_day    busiest_days  \
# ...

# %%
df_large.dtypes
# Out:
# product_id                       int64
# product_name                    object
# aisle_id                         int64
# department_id                    int64
# prices                         float64
# order_id                         int64
# user_id                          int64
# order_number                     int64
# orders_day_of_week               int64
# order_hour_of_day                int64
# days_since_prior_order         float64
# first_order                       bool
# add_to_cart_order                int64
# reordered                        int64
# _merge                        category
# price_range_loc                 object
# busiest_day                     object
# busiest_days                    object
# busiest_period_of_day           object
# max_order                        int64
# loyalty_flag                    object
# mean_product_price             float64
# spending_flag                   object
# median_days_between_orders     float64
# ...

# %%
df_large.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   product_id                  int64
#  1   product_name                object
#  2   aisle_id                    int64
#  3   department_id               int64
#  4   prices                      float64
#  5   order_id                    int64
#  6   user_id                     int64
#  7   order_number                int64
#  8   orders_day_of_week          int64
#  9   order_hour_of_day           int64
#  10  days_since_prior_order      float64
#  11  first_order                 bool
#  12  add_to_cart_order           int64
#  13  reordered                   int64
#  14  _merge                      category
#  15  price_range_loc             object
#  16  busiest_day                 object
#  17  busiest_days                object
#  18  busiest_period_of_day       object
# ...

# %%
df_large = df_large[['user_id', 'product_id', 'product_name', 'aisle_id', 'department_id', 'prices' ,
                    'order_id' ,'order_number','orders_day_of_week','order_hour_of_day','days_since_prior_order','first_order','add_to_cart_order',
                    'reordered','_merge','price_range_loc','busiest_day','busiest_days','busiest_period_of_day','max_order',
                     'loyalty_flag','mean_product_price','spending_flag','median_days_between_orders','order_frequency']]

# %%
df_large
# Out:
#           user_id  product_id                product_name  aisle_id  \
# 0             138           1  Chocolate Sandwich Cookies        61
# 1             138           1  Chocolate Sandwich Cookies        61
# 2             709           1  Chocolate Sandwich Cookies        61
# 3             764           1  Chocolate Sandwich Cookies        61
# 4             764           1  Chocolate Sandwich Cookies        61
# ...           ...         ...                         ...       ...
# 32404854   200215       49688      Fresh Foaming Cleanser        73
# 32404855   200377       49688      Fresh Foaming Cleanser        73
# 32404856   200873       49688      Fresh Foaming Cleanser        73
# 32404857   200873       49688      Fresh Foaming Cleanser        73
# 32404858   205926       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  order_id  order_number  orders_day_of_week  \
# ...

# %% [markdown]
# # 7 Merge the two df in the 'user_id'column

# %%
df_merged =df_large.merge(df, on ='user_id', indicator ='exist')

# %%
df_merged
# Out:
#           user_id  product_id                product_name  aisle_id  \
# 0             138           1  Chocolate Sandwich Cookies        61
# 1             138           1  Chocolate Sandwich Cookies        61
# 2             138         907        Premium Sliced Bacon       106
# 3             138         907        Premium Sliced Bacon       106
# 4             138        1000                    Apricots        18
# ...           ...         ...                         ...       ...
# 32404854    80734       49235         Organic Half & Half        53
# 32404855    74506       49520      Orange Sparkling Water       115
# 32404856    74506       49520      Orange Sparkling Water       115
# 32404857    74506       49520      Orange Sparkling Water       115
# 32404858    74506       49520      Orange Sparkling Water       115
#
#           department_id  prices  order_id  order_number  orders_day_of_week  \
# ...

# %% [markdown]
# # 8. Export this new dataframe as a pickle file so you can continue to use it in the second part of this task

# %%
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_derived_2.pkl'))
